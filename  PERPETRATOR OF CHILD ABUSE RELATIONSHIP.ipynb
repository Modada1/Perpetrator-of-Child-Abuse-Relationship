# %% [markdown]
# ## Task 1: Import Packages and Load data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Perpetrators of Child Abuse by Relationship.csv')
df = pd.DataFrame(data)

# %%
df
# Out:
#                    State    Parent  Child Daycare Provider  Foster Parent  \
# 0                Alabama    5919.0                    24.0           11.0
# 1                 Alaska    1854.0                     NaN           30.0
# 2                Arizona   11359.0                     NaN           40.0
# 3               Arkansas    4907.0                    38.0            3.0
# 4             California   48721.0                     NaN           89.0
# 5               Colorado    7430.0                    28.0           19.0
# 6            Connecticut    5052.0                    10.0            8.0
# 7               Delaware     697.0                     NaN            2.0
# 8   District of Columbia    1184.0                     NaN            NaN
# 9                Florida   17332.0                    61.0            6.0
# 10               Georgia    6533.0                    37.0           52.0
# 11                Hawaii    1008.0                     NaN           11.0
# ...

# %% [markdown]
# ## Task 2: Clean and Preprocess data
#
# ### Task 2.1: Check the number of rows and column

# %%
df.shape
# Out:
# (55, 14)

# %% [markdown]
# ### Task 2.2: Drop irrelevant rows

# %%
df.drop([52,53,54], axis=0, inplace = True)

# %%
df
# Out:
#                    State   Parent  Child Daycare Provider  Foster Parent  \
# 0                Alabama   5919.0                    24.0           11.0
# 1                 Alaska   1854.0                     0.0           30.0
# 2                Arizona  11359.0                     0.0           40.0
# 3               Arkansas   4907.0                    38.0            3.0
# 4             California  48721.0                     0.0           89.0
# 5               Colorado   7430.0                    28.0           19.0
# 6            Connecticut   5052.0                    10.0            8.0
# 7               Delaware    697.0                     0.0            2.0
# 8   District of Columbia   1184.0                     0.0            0.0
# 9                Florida  17332.0                    61.0            6.0
# 10               Georgia   6533.0                    37.0           52.0
# 11                Hawaii   1008.0                     0.0           11.0
# ...

# %% [markdown]
# ### Task 2.3: Check for missing values

# %%
null_values = pd.isnull(df).sum()
null_values
# Out:
# State                                         0
# Parent                                        1
# Child Daycare Provider                       13
# Foster Parent                                 3
# Friend and Neighbor                          25
# Group Home and Residential Facility Staff    11
# Legal Guardian                               13
# Multiple Relationships                        1
# Other                                         5
# Other Professional                           26
# Relative                                      1
# Unmarried Partner of Parent                   9
# Unknown                                       7
# Total Perpetrators                            1
# dtype: int64

# %% [markdown]
# ### Task 2.4: Fill in for missing values

# %%
df1 = df.fillna(0,inplace = True)

# %%
df
# Out:
#                    State    Parent  Child Daycare Provider  Foster Parent  \
# 0                Alabama    5919.0                    24.0           11.0
# 1                 Alaska    1854.0                     0.0           30.0
# 2                Arizona   11359.0                     0.0           40.0
# 3               Arkansas    4907.0                    38.0            3.0
# 4             California   48721.0                     0.0           89.0
# 5               Colorado    7430.0                    28.0           19.0
# 6            Connecticut    5052.0                    10.0            8.0
# 7               Delaware     697.0                     0.0            2.0
# 8   District of Columbia    1184.0                     0.0            0.0
# 9                Florida   17332.0                    61.0            6.0
# 10               Georgia    6533.0                    37.0           52.0
# 11                Hawaii    1008.0                     0.0           11.0
# ...

# %% [markdown]
# ### Task 2.5: Drop Duplicates

# %%
df.drop_duplicates()
# Out:
#                    State   Parent  Child Daycare Provider  Foster Parent  \
# 0                Alabama   5919.0                    24.0           11.0
# 1                 Alaska   1854.0                     0.0           30.0
# 2                Arizona  11359.0                     0.0           40.0
# 3               Arkansas   4907.0                    38.0            3.0
# 4             California  48721.0                     0.0           89.0
# 5               Colorado   7430.0                    28.0           19.0
# 6            Connecticut   5052.0                    10.0            8.0
# 7               Delaware    697.0                     0.0            2.0
# 8   District of Columbia   1184.0                     0.0            0.0
# 9                Florida  17332.0                    61.0            6.0
# 10               Georgia   6533.0                    37.0           52.0
# 11                Hawaii   1008.0                     0.0           11.0
# ...

# %% [markdown]
# ### Task 2.6: Show description of data

# %%
df.describe()
# Out:
#              Parent  Child Daycare Provider  Foster Parent  \
# count     52.000000               52.000000      52.000000
# mean    7717.326923               34.442308      28.346154
# std    10366.666902               64.595700      37.376665
# min        0.000000                0.000000       0.000000
# 25%     1942.500000                0.750000       5.750000
# 50%     3757.000000                9.500000      13.000000
# 75%     8165.500000               38.250000      41.250000
# max    48721.000000              300.000000     210.000000
#
#        Friend and Neighbor  Group Home and Residential Facility Staff  \
# count            52.000000                                  52.000000
# mean            103.000000                                  13.846154
# std             302.980553                                  19.443618
# min               0.000000                                   0.000000
# 25%               0.000000                                   1.000000
# ...

# %% [markdown]
# ### Task 2.7: Drop columns temporarily

# %%
dff1 = df.drop(['State','Total Perpetrators'], axis = 1)

# %%
dff1
# Out:
#      Parent  Child Daycare Provider  Foster Parent  Friend and Neighbor  \
# 0    5919.0                    24.0           11.0                166.0
# 1    1854.0                     0.0           30.0                  0.0
# 2   11359.0                     0.0           40.0                  0.0
# 3    4907.0                    38.0            3.0                107.0
# 4   48721.0                     0.0           89.0                  0.0
# 5    7430.0                    28.0           19.0                  1.0
# 6    5052.0                    10.0            8.0                 33.0
# 7     697.0                     0.0            2.0                  0.0
# 8    1184.0                     0.0            0.0                  0.0
# 9   17332.0                    61.0            6.0                  0.0
# 10   6533.0                    37.0           52.0                 25.0
# 11   1008.0                     0.0           11.0                  0.0
# ...

# %% [markdown]
# ## Task 3: Reporting
#
# ### Task 3.1: Total reported child abuse cases in the US

# %%
##sum of total perpetrators
dff3 = df["Total Perpetrators"].sum()
dff3
# Out:
# 517745.0

# %%
x = 'Reported Cases'
y = dff3

# %%
plt.figure(figsize=(2,4))
plt.bar(x,dff3, color="r",label = "dff3", width = 0.01)
plt.title("Total reported child abuse cases in the US")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# ### Task 3.2: Total reported cases by relationship of perpetrator

# %%
df5 = dff1.sum(axis=0) 
#df5.dtype
df5
# Out:
# Parent                                       401301.0
# Child Daycare Provider                         1791.0
# Foster Parent                                  1474.0
# Friend and Neighbor                            5356.0
# Group Home and Residential Facility Staff       720.0
# Legal Guardian                                 1616.0
# Multiple Relationships                        21405.0
# Other                                         19746.0
# Other Professional                             1223.0
# Relative                                      33639.0
# Unmarried Partner of Parent                   17488.0
# Unknown                                       11986.0
# dtype: float64

# %%
df6 = list(dff1.columns)
df6
# Out:
# ['Parent',
#  'Child Daycare Provider',
#  'Foster Parent',
#  'Friend and Neighbor',
#  'Group Home and Residential Facility Staff',
#  'Legal Guardian',
#  'Multiple Relationships',
#  'Other',
#  'Other Professional',
#  'Relative',
#  'Unmarried Partner of Parent',
#  'Unknown']

# %%
df5_fg = pd.DataFrame([df6, df5]).transpose()

#df5_fg = pd.DataFrame(df6, df5, columns=('Perpetrators','Total Perpetrator'))
df5_fg
# Out:
#                                             0         1
# 0                                      Parent  401301.0
# 1                      Child Daycare Provider    1791.0
# 2                               Foster Parent    1474.0
# 3                         Friend and Neighbor    5356.0
# 4   Group Home and Residential Facility Staff     720.0
# 5                              Legal Guardian    1616.0
# 6                      Multiple Relationships   21405.0
# 7                                       Other   19746.0
# 8                          Other Professional    1223.0
# 9                                    Relative   33639.0
# 10                Unmarried Partner of Parent   17488.0
# 11                                    Unknown   11986.0

# %%
#plt.subplots(figsize = (12,5))
#plt.barh(df6,df5, color="b",label = "All df5")
#plt.title("Total Perpetrator")
#plt.xlabel("Total")
#plt.ylabel("Perpetrators")
#plt.show()

import seaborn as sns
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
g = sns.barplot(data=df5_fg, x=0,y=1, color = 'r')
g.set_yscale('log')
g.set_ylim(500,400000)
plt.xlabel('Perpetrator By Relationship')
plt.ylabel('Total')
plt.title("Total Reported Cases by Relationship of Perpetrator")
# Out:
# Text(0.5, 1.0, 'Total Reported Cases by Relationship of Perpetrator')

# %% [markdown]
# ### Task 3.3: Top 5 reported cases by relationship of perpetrator

# %%
dff5 = df5_fg.sort_values(by = 1, ascending=False).head(5)
dff5
# Out:
#                               0         1
# 0                        Parent  401301.0
# 9                      Relative   33639.0
# 6        Multiple Relationships   21405.0
# 7                         Other   19746.0
# 10  Unmarried Partner of Parent   17488.0

# %%
plt.figure(figsize=(11,5))
import seaborn as sns
g = sns.barplot(data=dff5, x=0,y=1, color = 'r')
g.set_yscale('log')
g.set_ylim(1000,400000)
plt.xlabel('Perpetrators')
plt.ylabel('Total')
plt.title("Top 5 Reported Cases by Relationship of Perpetrator")
# Out:
# Text(0.5, 1.0, 'Top 5 Reported Cases by Relationship of Perpetrator')

# %%
##run codes with total perpetrators
dff2 = df.drop('Total Perpetrators', axis = 1)

# %%
dff2
# Out:
#                    State   Parent  Child Daycare Provider  Foster Parent  \
# 0                Alabama   5919.0                    24.0           11.0
# 1                 Alaska   1854.0                     0.0           30.0
# 2                Arizona  11359.0                     0.0           40.0
# 3               Arkansas   4907.0                    38.0            3.0
# 4             California  48721.0                     0.0           89.0
# 5               Colorado   7430.0                    28.0           19.0
# 6            Connecticut   5052.0                    10.0            8.0
# 7               Delaware    697.0                     0.0            2.0
# 8   District of Columbia   1184.0                     0.0            0.0
# 9                Florida  17332.0                    61.0            6.0
# 10               Georgia   6533.0                    37.0           52.0
# 11                Hawaii   1008.0                     0.0           11.0
# ...

# %% [markdown]
# ### Task 3.3: Total reported cases by country

# %%
#list of states and total reported cases
df3 = df[["State","Total Perpetrators"]]
df3
# Out:
#                    State  Total Perpetrators
# 0                Alabama              8376.0
# 1                 Alaska              2294.0
# 2                Arizona             12909.0
# 3               Arkansas              7118.0
# 4             California             55830.0
# 5               Colorado             10478.0
# 6            Connecticut              6497.0
# 7               Delaware               977.0
# 8   District of Columbia              1257.0
# 9                Florida             24927.0
# 10               Georgia              8107.0
# 11                Hawaii              1158.0
# 12                 Idaho              1774.0
# 13              Illinois             23858.0
# 14               Indiana             18477.0
# 15                  Iowa              8327.0
# 16                Kansas              2473.0
# 17              Kentucky             14731.0
# 18             Louisiana                 0.0
# 19                 Maine              3874.0
# ...

# %% [markdown]
# ### Task 3.4: Top 5 states by total reported cases

# %%
##top 5 states by total reported cases
df7 = df3.sort_values(by ="Total Perpetrators", ascending=False).head(5)
df7
# Out:
#          State  Total Perpetrators
# 4   California             55830.0
# 32    New York             52669.0
# 44       Texas             49969.0
# 22    Michigan             26210.0
# 9      Florida             24927.0

# %%
plt.figure(figsize=(11,5))
plt.xticks(rotation=90)
#g = sns.barplot(data=df7, x='State',y="Total Perpetrators")
#g.set_yscale('log')
#g.set_ylim(20000, 70000)
plt.bar(x= df7['State'], height =df7['Total Perpetrators'], color = 'r')
plt.xlabel('States')
plt.ylabel('Total')
plt.title("Top 5 States by Total Reported Cases")
# Out:
# Text(0.5, 1.0, 'Top 5 States by Total Reported Cases')

# %% [markdown]
# ### Task 3.5: % of cases in Top 5 states by total reported cases in the US

# %%
py = df7["State"].values.tolist()
py
# Out:
# ['California', 'New York', 'Texas', 'Michigan', 'Florida']

# %%
kl=df[df['State'].isin(py)]
kl
# Out:
#          State   Parent  Child Daycare Provider  Foster Parent  \
# 4   California  48721.0                     0.0           89.0
# 9      Florida  17332.0                    61.0            6.0
# 22    Michigan  20571.0                     1.0           86.0
# 32    New York  44233.0                   298.0          210.0
# 44       Texas  38241.0                   300.0           60.0
#
#     Friend and Neighbor  Group Home and Residential Facility Staff  \
# 4                   0.0                                        6.0
# 9                   0.0                                        0.0
# 22               2096.0                                       24.0
# 32                  0.0                                       99.0
# 44                184.0                                       73.0
#
#     Legal Guardian  Multiple Relationships   Other  Other Professional  \
# 4              0.0                  1718.0     2.0                 0.0
# ...

# %%
dff3
# Out:
# 517745.0

# %%
##Add new column to table show percentage of the top 5 state by the total number of perpetrators in the US
##Total perpetrators = dff3 = 517,745
kl["National_Percent"] = kl["Total Perpetrators"] / dff3 *100
kl1 = kl.sort_values(by ="National_Percent", ascending=False).head()
kl1
# Out:
# C:\Users\tomiw\AppData\Local\Temp\ipykernel_27288\3818290769.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kl["National_Percent"] = kl["Total Perpetrators"] / dff3 *100
#          State   Parent  Child Daycare Provider  Foster Parent  \
# 4   California  48721.0                     0.0           89.0
# 32    New York  44233.0                   298.0          210.0
# 44       Texas  38241.0                   300.0           60.0
# 22    Michigan  20571.0                     1.0           86.0
# 9      Florida  17332.0                    61.0            6.0
#
#     Friend and Neighbor  Group Home and Residential Facility Staff  \
# 4                   0.0                                        6.0
# ...

# %%
df51 = df5_fg[0].count()

# %%
kl1["Average"] = kl["Total Perpetrators"] / df51
kl1
# Out:
#          State   Parent  Child Daycare Provider  Foster Parent  \
# 4   California  48721.0                     0.0           89.0
# 32    New York  44233.0                   298.0          210.0
# 44       Texas  38241.0                   300.0           60.0
# 22    Michigan  20571.0                     1.0           86.0
# 9      Florida  17332.0                    61.0            6.0
#
#     Friend and Neighbor  Group Home and Residential Facility Staff  \
# 4                   0.0                                        6.0
# 32                  0.0                                       99.0
# 44                184.0                                       73.0
# 22               2096.0                                       24.0
# 9                   0.0                                        0.0
#
#     Legal Guardian  Multiple Relationships   Other  Other Professional  \
# 4              0.0                  1718.0     2.0                 0.0
# ...
